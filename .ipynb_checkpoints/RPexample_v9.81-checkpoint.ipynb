# %% [markdown]
# ### Importing modules

# %%
import numpy as np
import json
import matplotlib
import matplotlib.pyplot as plt
from scipy.stats import kendalltau
from scipy.stats import ttest_ind

# %% [markdown]
# # 1. Sending a query to Radiation Portal and processing outgoing JSON
# #### Reading the file should be replaced to the actual query later on

# %%
fin = open('ARMAS_fulloutput_v9.81.txt','r')
indata = json.loads(fin.read())
fin.close()

# %% [markdown]
# # 2. Understanding the properties of high-proton flights

# %%
prop_sxrflux = np.array(indata["b_avg_max"], dtype=float)
prop_pflux = np.array(indata["zpgt10_max"], dtype=float)
prop_ratio = np.array(indata["ARMAS_NAIRAS_flight_ratio"], dtype=float)
prop_L4ARMAS = np.array(indata["L4_median_flight_derived_effective_dose_rate_dEdt"], dtype=float)
prop_starttime = np.array(indata["Data_start_time_proc"])
prop_endtime = np.array(indata["Data_end_time_proc"])
prop_lonmin = np.array(indata["longitude_min"], dtype=float)
prop_lonmax = np.array(indata["longitude_max"], dtype=float)
prop_latmin = np.array(indata["latitude_min"], dtype=float)
prop_latmax = np.array(indata["latitude_max"], dtype=float)
prop_medalt = np.array(indata["Flight_median_altitude_nearcruise"], dtype=float)#*1000.0

# %%
# fixing parameters
prop_pflux[np.where(np.isnan(prop_pflux))] = -1.0
prop_ratio[np.where(np.isnan(prop_ratio))] = -1.0
prop_L4ARMAS[np.where(np.isnan(prop_L4ARMAS))] = -1.0
prop_sxrflux[np.where(np.isnan(prop_sxrflux))] = -1.0
indexes_highp = np.where(prop_pflux > 10.0)
print "Flight times:", prop_starttime[indexes_highp]
print "Flight longitudes (min):", prop_lonmin[indexes_highp]
print "Flight longitudes (max):", prop_lonmax[indexes_highp]
print "Flight latitudes (min):", prop_latmin[indexes_highp]
print "Flight latitudes (max):", prop_latmax[indexes_highp]
print "Flight median altitudes:", prop_medalt[indexes_highp]
# Out:
# Flight times: [u'2017-09-04 16:20:00' u'2017-09-05 16:43:49' u'2017-09-06 16:32:10'
#  u'2017-09-07 01:32:49' u'2017-09-08 04:34:00' u'2017-09-08 20:01:30']
# Flight longitudes (min): [-64.1 -68.  -79.9 -85.4 -85.3 -85.5]
# Flight longitudes (max): [-51.5  -56.7  -59.5  -65.8  -71.22 -73.3 ]
# Flight latitudes (min): [13.  13.  13.  17.  18.9 19.4]
# Flight latitudes (max): [28.5 29.8 26.4 27.9 29.  27.9]
# Flight median altitudes: [14100. 13800. 14100. 14100. 14100. 14400.]

# %% [markdown]
# #### Let us provide some summary of the flights:
# 1. The flights happened in September 4-8, 2017
# 2. The flight longitudes ranged from -85.5 to -51.5
# 3. The flight latitudes ranged from 13.0 to 29.0
# 4. The median altitudes were 13.8 km to 14.4 km
#
# Let us search how many flights else happened in September 6, 2016 - September 6, 2018, and occurred in the longitude range of (-95.5;-41.5), the latitude range of (3.0;39.0), and having median altitudes of (13100;15100).

# %% [markdown]
# # 3. Studying the properties of the same-region flights and determining the significance in measurement differences between two groups

# %%
indexes_lowp = np.where(( (prop_lonmin > -95.5) & (prop_lonmax < -41.5) & (prop_latmin > 3.0) & (prop_latmax < 39.0) & \
                       (prop_medalt > 13100.0) & (prop_medalt < 15100.0) & \
                       (prop_starttime > '2016-09-06 00:00:00') & (prop_starttime < '2018-09-06 00:00:00') & \
                       (prop_pflux < 10.0) ))
print indexes_lowp
# Out:
# (array([198, 199, 200, 201, 204, 205, 206, 208, 209, 210, 212, 213, 243,
#        247, 342, 349, 350, 352, 353, 354, 360, 362, 363, 391, 469, 474,
#        498, 499, 526], dtype=int64),)

# %%
print prop_ratio[indexes_highp]
print prop_ratio[indexes_lowp]
print "Student's t-test:", ttest_ind(prop_ratio[indexes_highp], prop_ratio[indexes_lowp], equal_var=True, nan_policy='omit')
print "Welch's t-test:", ttest_ind(prop_ratio[indexes_highp], prop_ratio[indexes_lowp], equal_var=False, nan_policy='omit')
# Out:
# [2.18559 1.66439 1.50893 1.57444 1.48453 1.63102]
# [1.7479  1.79479 1.34026 1.32548 1.52003 1.46811 1.60692 1.54673 1.46614
#  1.20233 1.22821 1.33885 1.27828 1.63375 1.08634 1.54327 1.55253 1.23938
#  1.55256 1.56494 1.66317 1.67024 1.30625 1.42853 1.39469 1.34342 1.49463
#  1.42465 1.38995]
# Student's t-test: Ttest_indResult(statistic=2.64027716703404, pvalue=0.0125544694518552)
# Welch's t-test: Ttest_indResult(statistic=2.0011091330646034, pvalue=0.09287419720377713)

# %%
print prop_L4ARMAS[indexes_highp][1:]
print prop_L4ARMAS[indexes_lowp]
print "Student's t-test:", ttest_ind(prop_ratio[indexes_highp][1:], prop_ratio[indexes_lowp], equal_var=True, nan_policy='omit')
print "Welch's t-test:", ttest_ind(prop_L4ARMAS[indexes_highp][1:], prop_L4ARMAS[indexes_lowp], equal_var=False, nan_policy='omit')
# Out:
# [7.76 8.08 9.41 8.43 8.43]
# [204.97 386.28   7.99   7.09   7.56   8.32   8.9    8.43   8.5    9.39
#   10.46  11.61   8.57  13.08   8.34   8.5    9.16  12.17   8.12   7.84
#    8.26  10.19   9.82  11.55  12.65  13.55  12.96  12.97  13.15]
# Student's t-test: Ttest_indResult(statistic=1.519077391869583, pvalue=0.13856249591846656)
# Welch's t-test: Ttest_indResult(statistic=-1.4746453118347262, pvalue=0.15145596210117618)

# %%
matplotlib.rcParams.update({'font.size':15})
im, ax = plt.subplots(2,2,figsize=(12,12),dpi=160)

ax[0,0].scatter(prop_sxrflux[indexes_lowp],prop_ratio[indexes_lowp], color='blue', alpha=1.0, s=150, label='Quiet Sun')
ax[0,0].scatter(prop_sxrflux[indexes_highp],prop_ratio[indexes_highp], color='red', alpha=1.0, s=250, label='SEP event')
ax[0,0].set(xlabel='log$_{10}$ 1-8$\AA$ SXR peak flux, W$\cdot$m$^{-2}$', \
          ylabel='ARMAS/NAIRAS dosage flight ratio', ylim=[0.9,2.3], xlim=[-8,-3.9])
ax[0,0].text(-7.9, 0.95, 'a)', fontsize=25)
ax[0,0].legend(loc=2)

ax[0,1].scatter(np.log10(prop_pflux[indexes_lowp]),prop_ratio[indexes_lowp], color='blue', alpha=1.0, s=150, label='Quiet Sun')
ax[0,1].scatter(np.log10(prop_pflux[indexes_highp]),prop_ratio[indexes_highp], color='red', alpha=1.0, s=250, label='SEP event')
ax[0,1].set(xlabel='log$_{10}$ >10 MeV proton peak flux, pfu', \
          ylabel='ARMAS/NAIRAS dosage flight ratio', ylim=[0.9,2.3], xlim=[-1,3])
ax[0,1].text(-0.9, 0.95, 'b)', fontsize=25)
ax[0,1].legend(loc=2)

ax[1,0].scatter(prop_sxrflux[indexes_lowp],np.log10(prop_L4ARMAS[indexes_lowp]), color='blue', alpha=1.0, s=150, label='Quiet Sun')
ax[1,0].scatter(prop_sxrflux[indexes_highp],np.log10(prop_L4ARMAS[indexes_highp]), color='red', alpha=1.0, s=250, label='SEP event')
ax[1,0].set(xlabel='log$_{10}$ 1-8$\AA$ SXR peak flux, W$\cdot$m$^{-2}$', ylabel='log$_{10}$ ARMAS median dosage rate, uSv/hr', \
            ylim=[0.8,1.25], xlim=[-8,-3.9])
ax[1,0].text(-7.9, 0.81, 'c)', fontsize=25)
ax[1,0].legend(loc=2)

ax[1,1].scatter(np.log10(prop_pflux[indexes_lowp]),np.log10(prop_L4ARMAS[indexes_lowp]), color='blue', alpha=1.0, s=150, label='Quiet Sun')
ax[1,1].scatter(np.log10(prop_pflux[indexes_highp]),np.log10(prop_L4ARMAS[indexes_highp]), color='red', alpha=1.0, s=250, label='SEP event')
ax[1,1].set(xlabel='log$_{10}$ >10 MeV proton peak flux, pfu', ylabel='log$_{10}$ ARMAS median dosage rate, uSv/hr', \
            ylim=[0.8,1.25], xlim=[-1,3])
ax[1,1].text(-0.9, 0.81, 'd)', fontsize=25)
ax[1,1].legend(loc=2)

plt.tight_layout()
plt.savefig('Flight_statistics_v10.20.png')
plt.savefig('Flight_statistics_v10.20.eps')
plt.show()



plt.tight_layout()
plt.savefig('ARMASNAIRAS_vs_fluxes_v9.81.eps')
plt.savefig('ARMASNAIRAS_vs_fluxes_v9.81.png')
plt.show()
plt.close()
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:17: RuntimeWarning: invalid value encountered in log10
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:23: RuntimeWarning: invalid value encountered in log10

# %%
indexes_allp = np.where(( (prop_lonmin > -95.5) & (prop_lonmax < -41.5) & (prop_latmin > 3.0) & (prop_latmax < 39.0) & \
                       (prop_medalt > 13100.0) & (prop_medalt < 15100.0) & \
                       (prop_starttime > '2016-09-06 00:00:00') & (prop_starttime < '2018-09-06 00:00:00') ))

# %%
print "SXR Kendall tau:", kendalltau(prop_sxrflux[indexes_allp], prop_ratio[indexes_allp])
print "Pflux Kendall tau:", kendalltau(prop_pflux[indexes_allp], prop_ratio[indexes_allp])
# Out:
# SXR Kendall tau: KendalltauResult(correlation=0.28403361344537814, pvalue=0.016393190067244122)
# Pflux Kendall tau: KendalltauResult(correlation=0.2605042016806723, pvalue=0.02772031386394527)

# %%
print prop_pflux[indexes_highp]
# Out:
# [ 13.0484 106.07    59.6425 364.855  154.125   11.2305]

# %% [markdown]
# # 4. General properties of the flights.

# %%
prop_pflux = np.array(indata["zpgt10_max"], dtype=float)
prop_sxrflux = np.array(indata["b_avg_max"], dtype=float)
prop_ratio = np.array(indata["ARMAS_NAIRAS_flight_ratio"], dtype=float)
prop_L4ARMAS = np.array(indata["L4_median_flight_derived_effective_dose_rate_dEdt"], dtype=float)
prop_lonmin = np.array(indata["longitude_min"], dtype=float)
prop_lonmax = np.array(indata["longitude_max"], dtype=float)
prop_latmin = np.array(indata["latitude_min"], dtype=float)
prop_latmax = np.array(indata["latitude_max"], dtype=float)
prop_medalt = np.array(indata["Flight_median_altitude_nearcruise"], dtype=float)
prop_ftime = np.array(indata["Data_start_time_proc"])

# for ratio Welch's test
gi_sep_r = np.where(( (np.isnan(prop_ratio) == False) & (prop_pflux >= 10.0) ))
gi_qui_r = np.where(( (np.isnan(prop_ratio) == False) & (prop_pflux < 10.0) ))
gi_all_r = np.where(( (np.isnan(prop_ratio) == False) ))

# for correlations of ratio and proton flux
gi_sep_rp = np.where(( (np.isnan(prop_ratio) == False) & (np.isnan(prop_pflux) == False) & (prop_pflux >= 10.0) ))
gi_qui_rp = np.where(( (np.isnan(prop_ratio) == False) & (np.isnan(prop_pflux) == False) & (prop_pflux < 10.0) ))
gi_all_rp = np.where(( (np.isnan(prop_ratio) == False) & (np.isnan(prop_pflux) == False) ))

# for correlations of ratio and sxr flux
gi_sep_rx = np.where(( (np.isnan(prop_ratio) == False) & (np.isnan(prop_sxrflux) == False) & (prop_pflux >= 10.0) & (prop_sxrflux >= -7.0) ))
gi_qui_rx = np.where(( (np.isnan(prop_ratio) == False) & (np.isnan(prop_sxrflux) == False) & (prop_pflux < 10.0) & (prop_sxrflux >= -7.0) ))
gi_all_rx = np.where(( (np.isnan(prop_ratio) == False) & (np.isnan(prop_sxrflux) == False) & (prop_sxrflux >= -7.0) ))

# for dosage Welch's test
gi_sep_d = np.where(( (np.isnan(prop_L4ARMAS) == False) & (prop_pflux >= 10.0) ))
gi_qui_d = np.where(( (np.isnan(prop_L4ARMAS) == False) & (prop_pflux < 10.0) ))
gi_all_d = np.where(( (np.isnan(prop_L4ARMAS) == False) ))

# for correlations of dosage and proton flux
gi_sep_dp = np.where(( (np.isnan(prop_L4ARMAS) == False) & (np.isnan(prop_pflux) == False) & (prop_pflux >= 10.0) ))
gi_qui_dp = np.where(( (np.isnan(prop_L4ARMAS) == False) & (np.isnan(prop_pflux) == False) & (prop_pflux < 10.0) ))
gi_all_dp = np.where(( (np.isnan(prop_L4ARMAS) == False) & (np.isnan(prop_pflux) == False) ))

# for correlations of dosage and sxr flux
gi_sep_dx = np.where(( (np.isnan(prop_L4ARMAS) == False) & (np.isnan(prop_sxrflux) == False) & (prop_pflux >= 10.0) & (prop_sxrflux >= -7.0) ))
gi_qui_dx = np.where(( (np.isnan(prop_L4ARMAS) == False) & (np.isnan(prop_sxrflux) == False) & (prop_pflux < 10.0) & (prop_sxrflux >= -7.0) ))
gi_all_dx = np.where(( (np.isnan(prop_L4ARMAS) == False) & (np.isnan(prop_sxrflux) == False) & (prop_sxrflux >= -7.0) ))
# Out:
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:13: RuntimeWarning: invalid value encountered in greater_equal
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:14: RuntimeWarning: invalid value encountered in less
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:18: RuntimeWarning: invalid value encountered in greater_equal
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:19: RuntimeWarning: invalid value encountered in less
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:23: RuntimeWarning: invalid value encountered in greater_equal
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:24: RuntimeWarning: invalid value encountered in less
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:24: RuntimeWarning: invalid value encountered in greater_equal
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:25: RuntimeWarning: invalid value encountered in greater_equal
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:28: RuntimeWarning: invalid value encountered in greater_equal
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:29: RuntimeWarning: invalid value encountered in less
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:33: RuntimeWarning: invalid value encountered in greater_equal
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:34: RuntimeWarning: invalid value encountered in less
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:38: RuntimeWarning: invalid value encountered in greater_equal
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:39: RuntimeWarning: invalid value encountered in less
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:39: RuntimeWarning: invalid value encountered in greater_equal
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:40: RuntimeWarning: invalid value encountered in greater_equal

# %%
matplotlib.rcParams.update({'font.size':15})
im, ax = plt.subplots(2,2,figsize=(12,12),dpi=160)

ax[0,0].scatter(prop_sxrflux[gi_qui_rx],prop_ratio[gi_qui_rx], color='blue', alpha=0.25, s=150, label='Quiet conditions')
ax[0,0].scatter(prop_sxrflux[gi_sep_rx],prop_ratio[gi_sep_rx], color='red', alpha=1.0, s=250, label='SEP event')
ax[0,0].set(xlabel='log$_{10}$ 1-8$\AA$ SXR peak flux, W$\cdot$m$^{-2}$', ylabel='ARMAS/NAIRAS dosage flight ratio', \
            ylim=[0.2,2.8], xlim=[-7.1,-3.9])
ax[0,0].legend(loc=4)
print kendalltau(prop_sxrflux[gi_all_rx],prop_ratio[gi_all_rx])

ax[0,1].scatter(np.log10(prop_pflux[gi_qui_rp]),prop_ratio[gi_qui_rp], color='blue', alpha=0.25, s=150, label='Quiet conditions')
ax[0,1].scatter(np.log10(prop_pflux[gi_sep_rp]),prop_ratio[gi_sep_rp], color='red', alpha=1.0, s=250, label='SEP event')
ax[0,1].set(xlabel='log$_{10}$ >10 MeV proton peak flux, pfu', ylabel='ARMAS/NAIRAS dosage flight ratio', \
            ylim=[0.2,2.8], xlim=[-1,3])
ax[0,1].legend(loc=4)
print kendalltau(np.log10(prop_pflux[gi_all_rp]),prop_ratio[gi_all_rp])

ax[1,0].scatter(prop_sxrflux[gi_qui_dx],np.log10(prop_L4ARMAS[gi_qui_dx]), color='blue', alpha=0.25, s=150, label='Quiet conditions')
ax[1,0].scatter(prop_sxrflux[gi_sep_dx],np.log10(prop_L4ARMAS[gi_sep_dx]), color='red', alpha=1.0, s=250, label='SEP event')
ax[1,0].set(xlabel='log$_{10}$ 1-8$\AA$ SXR peak flux, W$\cdot$m$^{-2}$', ylabel='log$_{10}$ ARMAS median dosage rate, uSv/hr', \
            ylim=[0.2,1.5], xlim=[-7.1,-3.9])
ax[1,0].legend(loc=4)
print kendalltau(prop_sxrflux[gi_all_dx],np.log10(prop_L4ARMAS[gi_all_dx]))

ax[1,1].scatter(np.log10(prop_pflux[gi_qui_dp]),np.log10(prop_L4ARMAS[gi_qui_dp]), color='blue', alpha=0.25, s=150, label='Quiet conditions')
ax[1,1].scatter(np.log10(prop_pflux[gi_sep_dp]),np.log10(prop_L4ARMAS[gi_sep_dp]), color='red', alpha=1.0, s=250, label='SEP event')
ax[1,1].set(xlabel='log$_{10}$ >10 MeV proton peak flux, pfu', ylabel='log$_{10}$ ARMAS median dosage rate, uSv/hr', \
            ylim=[0.2,1.5], xlim=[-1,3])
ax[1,1].legend(loc=4)
print kendalltau(np.log10(prop_pflux[gi_all_dp]),np.log10(prop_L4ARMAS[gi_all_dp]))

plt.tight_layout()
plt.savefig('Flight_statistics_v9.81.png')
plt.savefig('Flight_statistics_v9.81.eps')
plt.show()
# Out:
# KendalltauResult(correlation=0.26969717287349054, pvalue=2.8660509187571354e-11)
# KendalltauResult(correlation=0.0652153158484591, pvalue=0.01491237990327032)
# KendalltauResult(correlation=0.04150628648301704, pvalue=0.2946382294781602)
# KendalltauResult(correlation=0.0949336538157811, pvalue=0.00025870457398170907)
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:16: RuntimeWarning: divide by zero encountered in log10
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:20: RuntimeWarning: divide by zero encountered in log10
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:22: RuntimeWarning: divide by zero encountered in log10
# C:\Program Files\Anaconda2\lib\site-packages\ipykernel\__main__.py:26: RuntimeWarning: divide by zero encountered in log10
